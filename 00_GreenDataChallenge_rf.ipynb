# %% [markdown]
# ![thumbnail.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # SMBC Group GREEN×DATA Challengeチュートリアル
# この度は**SMBC Group GREEN×DATA Challenge**にご参加いただきありがとうございます。\
# このチュートリアルは分析コンペティションに初めて参加する方にもスムーズに取り組んでいただけるように作成しています。\
# ぜひ参考にしてみてください。

# %% [markdown]
# # 1.課題を理解しよう
# 今回は木の健康状態の予測です。ニューヨークの市街地で管理されている木々に関する情報を分析します。

# %% [markdown]
# # 2.データをダウンロードしよう
# 課題を理解した後は、データタブからデータをダウンロードしてみましょう。 今回は3種類のデータが用意されており、下記ページのダウンロードアイコンをクリックするとデータをダウンロードできます。\
# [https://signate.jp/competitions/1247/data](https://signate.jp/competitions/1247/data)
#
#
# 学習用データ　：モデルの学習に使用するデータ（木々の情報＋健康状態）\
# 評価用データ　：予測に使用するデータ（木々の情報のみ）\
# 応募用ファイル：予測結果の投稿に使用するサンプルフォーマット

# %% [markdown]
# # 3.環境を整えよう
# データをダウンロードしたら分析環境を整備しましょう。なお、本チュートリアルでは次の環境を利用しています。
# - Google Colaboratory
# 画像を参考にして、データの配置、Google Colaboratoryの起動を行ってみましょう。
#
# 1.   任意のGoogleDriveにフォルダを作成しデータを格納
# 2.   そのフォルダ内で「＋　新規」ボタンから画像のようにGoogle Colaboratoryを起動\
# ＊今回はMyDrive内にSMFGというフォルダを作成し、その中にデータを格納しています。
#
# ![cap.png](data:image/png;base64,...)

# %% [markdown]
# # 4.データ読み込もう
# Google Colaboratoryが起動できたらデータを読み込みましょう。\
# まずは下記のコードで、Google Colaboratoryと自分のGoogle Driveを接続します。\
# 別のタブでGoogleアカウントの選択、アクセスリクエストの許可を行います。

# %% [markdown]
# 今回はマイドライブの中にSMFGというフォルダを作成し、その中にデータを格納していますので、パスは下記のようになります。\
# `/content/drive/MyDrive/SMFG`

# %%
# !pip install auto-sklearn
# !pip install PipelineProfiler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting auto-sklearn
#   Using cached auto-sklearn-0.15.0.tar.gz (6.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [17 lines of output]
#       Traceback (most recent call last):
#         File "C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "C:\Users\Owner\AppData\Local\Temp\pip-build-env-y7kt78jh\overlay\Lib\site-packages\setuptools\build_meta.py", line 325, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=['wheel'])
#         File "C:\Users\Owner\AppData\Local\Temp\pip-build-env-y7kt78jh\overlay\Lib\site-packages\setuptools\build_meta.py", line 295, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\Owner\AppData\Local\Temp\pip-build-env-y7kt78jh\overlay\Lib\site-packages\setuptools\build_meta.py", line 480, in run_setup
#           super(_BuildMetaLegacyBackend, self).run_setup(setup_script=setup_script)
#         File "C:\Users\Owner\AppData\Local\Temp\pip-build-env-y7kt78jh\overlay\Lib\site-packages\setuptools\build_meta.py", line 311, in run_setup
#           exec(code, locals())
#         File "<string>", line 10, in <module>
#       ValueError: Detected unsupported operating system: win32. Please check the compability information of auto-sklearn: https://automl.github.io/auto-sklearn/master/installation.html#windows-osx-compatibility
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Defaulting to user installation because normal site-packages is not writeable
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: PipelineProfiler in c:\users\owner\appdata\roaming\python\python310\site-packages (0.1.18)
# Requirement already satisfied: python-dateutil in c:\users\owner\appdata\roaming\python\python310\site-packages (from PipelineProfiler) (2.8.2)
# Requirement already satisfied: numpy in c:\users\owner\appdata\roaming\python\python310\site-packages (from PipelineProfiler) (1.23.1)
# Requirement already satisfied: scipy in c:\users\owner\appdata\roaming\python\python310\site-packages (from PipelineProfiler) (1.8.1)
# Requirement already satisfied: scikit-learn in c:\users\owner\appdata\roaming\python\python310\site-packages (from PipelineProfiler) (1.1.1)
# Requirement already satisfied: networkx in c:\users\owner\appdata\roaming\python\python310\site-packages (from PipelineProfiler) (2.8.7)
# Requirement already satisfied: notebook in c:\users\owner\appdata\roaming\python\python310\site-packages (from PipelineProfiler) (7.0.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from notebook->PipelineProfiler) (2.11.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from notebook->PipelineProfiler) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\owner\appdata\roaming\python\python310\site-packages (from notebook->PipelineProfiler) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\owner\appdata\roaming\python\python310\site-packages (from notebook->PipelineProfiler) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from notebook->PipelineProfiler) (6.2)
# Requirement already satisfied: six>=1.5 in c:\users\owner\appdata\roaming\python\python310\site-packages (from python-dateutil->PipelineProfiler) (1.12.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from scikit-learn->PipelineProfiler) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from scikit-learn->PipelineProfiler) (3.1.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (3.6.2)
# Requirement already satisfied: argon2-cffi in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (23.1.0)
# Requirement already satisfied: jinja2 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (5.5.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (7.11.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (5.8.0)
# Requirement already satisfied: overrides in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (7.4.0)
# Requirement already satisfied: packaging in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (21.3)
# Requirement already satisfied: prometheus-client in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.19.0)
# Requirement already satisfied: pywinpty in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.0.12)
# Requirement already satisfied: pyzmq>=24 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (25.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.18.0)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (5.9.0)
# Requirement already satisfied: websocket-client in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.5.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (6.15.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (2.2.1)
# Requirement already satisfied: tomli in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (2.0.1)
# Requirement already satisfied: babel>=2.10 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (4.20.0)
# Requirement already satisfied: requests>=2.31 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\owner\appdata\roaming\python\python310\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from async-lru>=1.0.0->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (4.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.1.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (0.13.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (3.0.0)
# Requirement already satisfied: pywin32>=300 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (303)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (6.0)
# Requirement already satisfied: rfc3339-validator in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (4.8.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.16.1)
# Requirement already satisfied: tinycss2 in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\owner\appdata\roaming\python\python310\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.16.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\owner\appdata\roaming\python\python310\site-packages (from packaging->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (3.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\owner\appdata\roaming\python\python310\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (2.0.12)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\appdata\roaming\python\python310\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->PipelineProfiler) (2021.10.8)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\owner\appdata\roaming\python\python310\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (1.6.2)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (8.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (1.5.5)
# Requirement already satisfied: psutil in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (5.9.1)
# Requirement already satisfied: webencodings in c:\users\owner\appdata\roaming\python\python310\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (0.5.1)
# Requirement already satisfied: backcall in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.2.0)
# Requirement already satisfied: decorator in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (3.0.30)
# Requirement already satisfied: setuptools>=18.5 in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (61.1.0)
# Requirement already satisfied: stack-data in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.3.0)
# Requirement already satisfied: colorama in c:\users\owner\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.4.4)
# Requirement already satisfied: fqdn in c:\users\owner\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\owner\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.4)
# Requirement already satisfied: uri-template in c:\users\owner\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\owner\appdata\roaming\python\python310\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.15.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\owner\appdata\roaming\python\python310\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.3.1)
# Requirement already satisfied: pycparser in c:\users\owner\appdata\roaming\python\python310\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\owner\appdata\roaming\python\python310\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (1.3.0)
# Requirement already satisfied: executing in c:\users\owner\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.9.0)
# Requirement already satisfied: asttokens in c:\users\owner\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\owner\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->PipelineProfiler) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\owner\appdata\roaming\python\python310\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->PipelineProfiler) (2.8.19.14)

# %%
import pandas as pd
train = pd.read_csv('./source/train.csv', index_col=0) # 学習用データ
test = pd.read_csv('./source/test.csv', index_col=0) # 学習用データ   # 評価用データ
sample_submit = pd.read_csv('./source/sample_submission.csv', index_col=0, header=None) # 応募用サンプルファイル

# %% [markdown]
# # 5.データの概要を確認しよう
# 読み込んだ学習用データの先頭5行を表示してみましょう。

# %%
train.head()
# Out:
#    created_at  tree_dbh curb_loc  health steward   guards  sidewalk  \
# 0  2015-06-29        14   OnCurb       1     NaN      NaN    Damage
# 1  2016-09-21         5   OnCurb       1    3or4  Helpful  NoDamage
# 2  2015-09-13        26   OnCurb       2     NaN      NaN  NoDamage
# 3  2016-05-09        15   OnCurb       0     NaN      NaN    Damage
# 4  2016-06-24        23   OnCurb       1     NaN      NaN  NoDamage
#
#          user_type            problems          spc_common  ...   nta  \
# 0        Volunteer                 NaN         English oak  ...  QN45
# 1        Volunteer                 NaN  crimson king maple  ...  BX05
# 2        Volunteer  StonesBranchLights         English oak  ...  SI01
# 3  NYC Parks Staff                 NaN         honeylocust  ...  SI11
# 4        Volunteer              Stones    London planetree  ...  MN03
#
#                                      nta_name borocode  boro_ct  \
# 0        Douglas Manor-Douglaston-Little Neck        4  4152901
# 1                  Bedford Park-Fordham North        2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville        5  5017011
# 3      Charleston-Richmond Valley-Tottenville        5  5024401
# 4           Central Harlem North-Polo Grounds        1  1022102
#
#         boroname       zip_city cb_num  st_senate  st_assem  cncldist
# 0         Queens    Little Neck    411         11        25        23
# 1          Bronx          Bronx    207         33        78        15
# 2  Staten Island  Staten Island    503         24        62        51
# 3  Staten Island  Staten Island    503         24        62        51
# 4      Manhattan       New York    110         30        70         9
#
# [5 rows x 21 columns]

# %% [markdown]
# 1行で1本の木の情報を表していて、カラムは21種類あることが分かります。\
# 各カラムの意味は、データタブに記載されているのでそれと照らし合わせて確認できます。\
# health（健康状態）が今回の予測の対象である目的変数で、0がFair（普通）、1がGood（良い）、2がPoor（悪い）です。
#
# 評価用データには、目的変数（health）はありません。その他のカラムは学習用データと同じです。\
# つまり、答えのある学習用データの木の情報を元にして機械学習により木の健康状態の法則をモデル化し、そのモデルを評価用データに当てはめて、評価用データに記録されている各木が0、1、2のどれに当てはまるかを予測することが課題になります。
#
# 目的変数の値の学習用データでの出現数をカウントしてみましょう。

# %%
train['health'].value_counts()
# Out:
# 1    15751
# 0     3535
# 2      698
# Name: health, dtype: int64

# %% [markdown]
# 1（状態が良い）の木が一番多く、2（状態が悪い）の木が少ない不均衡データとなっています。

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19984 entries, 0 to 19983
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  19984 non-null  object
#  1   tree_dbh    19984 non-null  int64
#  2   curb_loc    19984 non-null  object
#  3   health      19984 non-null  int64
#  4   steward     5101 non-null   object
#  5   guards      5041 non-null   object
#  6   sidewalk    19984 non-null  object
#  7   user_type   19984 non-null  object
#  8   problems    7741 non-null   object
#  9   spc_common  19984 non-null  object
#  10  spc_latin   19984 non-null  object
#  11  nta         19984 non-null  object
#  12  nta_name    19984 non-null  object
#  13  borocode    19984 non-null  int64
#  14  boro_ct     19984 non-null  int64
#  15  boroname    19984 non-null  object
#  16  zip_city    19984 non-null  object
#  17  cb_num      19984 non-null  int64
#  18  st_senate   19984 non-null  int64
#  19  st_assem    19984 non-null  int64
#  20  cncldist    19984 non-null  int64
# dtypes: int64(8), object(13)
# memory usage: 3.4+ MB

# %% [markdown]
# また具体的な名称などのカテゴリ変数が多いデータとなっています。

# %% [markdown]
# # 6.前処理を行おう
# 機械学習によるモデルがより高い精度で学習ができるように、データをきれいにする前処理を行います。\
# まずは欠損値の処理のみを行います。

# %%
train.isnull().sum()
# Out:
# created_at        0
# tree_dbh          0
# curb_loc          0
# health            0
# steward       14883
# guards        14943
# sidewalk          0
# user_type         0
# problems      12243
# spc_common        0
# spc_latin         0
# nta               0
# nta_name          0
# borocode          0
# boro_ct           0
# boroname          0
# zip_city          0
# cb_num            0
# st_senate         0
# st_assem          0
# cncldist          0
# dtype: int64

# %% [markdown]
# steward、guards、problemsという列に欠損を含むことがわかりました。\
# stewardは木の管理者数、guardsは木を保護するためのガード状況、problemsは木に関連する問題という意味です。\
# それぞれどのような要素になっているか確認してみます。

# %%
train['steward'].value_counts()
# Out:
# 1or2       3999
# 3or4       1079
# 4orMore      23
# Name: steward, dtype: int64

# %%
train['guards'].value_counts()
# Out:
# Helpful    3650
# Unsure      737
# Harmful     654
# Name: guards, dtype: int64

# %%
train['problems'].value_counts()
# Out:
# Stones                                  2219
# BranchLights                            1036
# StonesBranchLights                       762
# BranchOther                              408
# RootOther                                333
#                                         ...
# StonesRootOtherTrunkOtherBranchOther       8
# StonesRootOtherWiresRopeBranchOther        5
# StonesMetalGratesTrunkOther                4
# TrunkLightsBranchLightsBranchOther         4
# WiresRopeTrunkLightsBranchLights           4
# Name: problems, Length: 73, dtype: int64

# %% [markdown]
# 要素を確認しました。\
# これらのデータの欠損は何もないことを表すという解釈ができそうです。\
# なので欠損値は'NULL'というカテゴリに置き換え、欠損であるという情報は残しておきます。

# %%
train.fillna('NULL', inplace=True)

# %% [markdown]
# 次に、problemsに関しては、木ごとに問題の詳細がことなるため、要素数が多そうです。\
# 確認してみましょう。

# %%
train['problems'].nunique()
# Out:
# 74

# %% [markdown]
# 73種類の問題とNULL（問題なし）があることがわかりました。\
# 今回は問題があるかどうかの2値に変換して分析を進めようと思います。

# %%
train['bool_problems'] = train['problems'].apply(lambda x: 0 if x=='NULL' else 1)

# %%
train.head()
# Out:
#    created_at  tree_dbh curb_loc  health steward   guards  sidewalk  \
# 0  2015-06-29        14   OnCurb       1    NULL     NULL    Damage
# 1  2016-09-21         5   OnCurb       1    3or4  Helpful  NoDamage
# 2  2015-09-13        26   OnCurb       2    NULL     NULL  NoDamage
# 3  2016-05-09        15   OnCurb       0    NULL     NULL    Damage
# 4  2016-06-24        23   OnCurb       1    NULL     NULL  NoDamage
#
#          user_type            problems          spc_common  ...  \
# 0        Volunteer                NULL         English oak  ...
# 1        Volunteer                NULL  crimson king maple  ...
# 2        Volunteer  StonesBranchLights         English oak  ...
# 3  NYC Parks Staff                NULL         honeylocust  ...
# 4        Volunteer              Stones    London planetree  ...
#
#                                      nta_name borocode  boro_ct  \
# 0        Douglas Manor-Douglaston-Little Neck        4  4152901
# 1                  Bedford Park-Fordham North        2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville        5  5017011
# 3      Charleston-Richmond Valley-Tottenville        5  5024401
# 4           Central Harlem North-Polo Grounds        1  1022102
#
#         boroname       zip_city cb_num st_senate  st_assem  cncldist  \
# 0         Queens    Little Neck    411        11        25        23
# 1          Bronx          Bronx    207        33        78        15
# 2  Staten Island  Staten Island    503        24        62        51
# 3  Staten Island  Staten Island    503        24        62        51
# 4      Manhattan       New York    110        30        70         9
#
#    bool_problems
# 0              0
# 1              0
# 2              1
# 3              0
# 4              1
#
# [5 rows x 22 columns]

# %% [markdown]
# problemsを参照して、問題がある木には1, ない木には0とする新たな特徴量bool_problemsを作成しました。

# %% [markdown]
# # 7.可視化をしてデータを理解しよう
# 次に、目的変数と他の変数との関連を確認します。\
# まずは「tree_dbh」（木の直径）と「health」との関係から可視化してみます。

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

plt.figure(figsize=(10, 6))
sns.boxplot(x='health', y='tree_dbh', data=train)
plt.title('Relationship between "tree_dbh" and "health"')
plt.show()

# %% [markdown]
# 木の直径と目的変数の関係を示すボックスプロットを作成しました。\
# このプロットから、健康状態によって多少木の直径が関係しているように見て取れます。
#
# さらに、カテゴリ変数についても目的変数との関係を可視化してみましょう。

# %%
categorical_features = ['curb_loc', 'sidewalk', 'steward', 'guards', 'user_type', 'bool_problems']

fig, axes = plt.subplots(len(categorical_features), 1, figsize=(10, 20))

for i, feature in enumerate(categorical_features):
    sns.countplot(x='health', hue=feature, data=train, ax=axes[i])
    axes[i].set_title(f'Health Status by {feature}')
    axes[i].legend(title=feature, loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 8.モデリングをしてみよう
# ここまでの分析で使用した特徴量を用いて、モデリングを行います。\
# モデリングの準備としてtestデータにも同様の前処理を行なっておきましょう。

# %%
test.fillna('NULL', inplace=True)
test['bool_problems'] = test['problems'].apply(lambda x: 0 if x=='NULL' else 1)

# %% [markdown]
# 作成したモデルの精度が良いかどうかを事前に判断するために、学習用データ（train）から検証用データを作ります。

# %%
train.shape
# Out:
# (19984, 22)

# %%
from sklearn.model_selection import train_test_split
train, valid = train_test_split(train, test_size=0.2, stratify=train['health'], random_state=82) # stratifyを設定することで目的変数の分布を保ったまま分割することができます。

# %%
train.shape
# Out:
# (15987, 22)

# %%
valid.shape
# Out:
# (3997, 22)

# %%
# 使用する特徴量の選択
select_cols = ['tree_dbh', 'curb_loc', 'sidewalk', 'steward', 'guards', 'user_type', 'bool_problems']

# 目的変数とそれ以外に学習用データを分割
x_train = train[select_cols]
y_train = train['health']
x_valid = valid[select_cols]
y_valid = valid['health']

# カテゴリのままでは学習できないのでワンホットエンコーディングで数値化
x_train = pd.get_dummies(x_train)
x_valid = pd.get_dummies(x_valid)
test =pd.get_dummies(test[select_cols])

# %% [markdown]
# これでモデリングの準備が整いました。\
# 今回はRandomForestを使ってモデリングを行なっていきます。\
# このコンペティションの評価指標はmacro_f1scoreですので、それでスコアも計算してみます。

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

model = RandomForestClassifier()
model.fit(x_train, y_train)

valid_predictions = model.predict(x_valid)
valid_f1 = f1_score(y_valid, valid_predictions, average='macro')
print(f"Validation F1 Score (Macro): {valid_f1}")
# Out:
# Validation F1 Score (Macro): 0.3181875931362297

# %% [markdown]
# これでモデルが作成できました。
#
# 学習したモデルにtestデータを入力すると、testデータに対する木の健康状態を予測してくれます。

# %%
pred = model.predict(test)
print(pred[:5])
# Out:
# [1 1 1 1 1]

# %% [markdown]
# # 9.予測結果を投稿しよう
# 応募用サンプルファイルで予測結果が格納されている1列目の値を、今回出力した予測結果に置き換えた上で、ヘッダ無しcsv形式のファイルとして保存しましょう。

# %%
sample_submit[1] = pred
sample_submit.to_csv('./submit/submit_sample2.csv', header=None)

# %% [markdown]
# これでGoogle Driveの中のSMFGフォルダ内に投稿用ファイルが作成されます。\
# このデータをダウンロードして、コンペティションサイトの投稿ボタンからファイルの投稿を行ってみてください。

# %% [markdown]
# # 10.より良い精度を出すために
# お疲れ様でした！無事予測結果をすることができました。\
# 今回は簡易的に前処理、特徴量選択、モデリングを行いました。\
# ここからさらにより良い精度を出すためには下記のことを参考にしてみてください。
# - 場所関連の情報を分析に取り入れる\
# 今回は場所関連の特徴量は使用しませんでしたが、工業地帯や木にとって育ちにくいような気候など、木の健康状態に影響を及ぼすかもしれません。
# - 複雑モデリングを行う\
# 今回は比較的計算に時間がかからないRandomForestを使用しましたが、ディープラーニングやAutoMLなどを使用することで、より精度の高いモデルを作成することができるかもしれません。
