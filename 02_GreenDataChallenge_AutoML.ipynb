# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tpot import TPOTClassifier
from sklearn.metrics import f1_score

# データの読み込み
train = pd.read_csv('./source/train.csv', index_col=0)
test = pd.read_csv('./source/test.csv', index_col=0)
sample_submit = pd.read_csv('./source/sample_submission.csv', index_col=0, header=None)

from sklearn.preprocessing import LabelEncoder

# カテゴリ変数を数値化する関数
def encode_categorical_variables(df, categorical_variables):
    le = LabelEncoder()
    for col in categorical_variables:
        df[col] = le.fit_transform(df[col].astype(str))
    return df

# カテゴリ変数の要素一覧を表示
categorical_variables = ['curb_loc', 'steward', 'guards', 'sidewalk', 'user_type', 'boroname']

for col in categorical_variables:
    unique_elements = train[col].unique()
    print(f'{col}の要素: {unique_elements}')

# カテゴリ変数を数値化
train_encoded = encode_categorical_variables(train, categorical_variables)
test_encoded = encode_categorical_variables(test, categorical_variables)

print(train_encoded)
print(test_encoded)
# Out:
# curb_locの要素: ['OnCurb' 'OffsetFromCurb']
# stewardの要素: [nan '3or4' '1or2' '4orMore']
# guardsの要素: [nan 'Helpful' 'Harmful' 'Unsure']
# sidewalkの要素: ['Damage' 'NoDamage']
# user_typeの要素: ['Volunteer' 'NYC Parks Staff' 'TreesCount Staff']
# boronameの要素: ['Queens' 'Bronx' 'Staten Island' 'Manhattan' 'Brooklyn']
#        created_at  tree_dbh  curb_loc  health  steward  guards  sidewalk  \
# 0      2015-06-29        14         1       1        3       3         0
# 1      2016-09-21         5         1       1        1       1         1
# 2      2015-09-13        26         1       2        3       3         1
# 3      2016-05-09        15         1       0        3       3         0
# 4      2016-06-24        23         1       1        3       3         1
# ...           ...       ...       ...     ...      ...     ...       ...
# 19979  2016-07-15        19         1       2        3       3         0
# 19980  2016-07-08         5         1       1        3       3         1
# 19981  2015-08-20        21         1       0        3       3         0
# 19982  2016-06-20         4         1       1        0       3         1
# 19983  2015-08-19        31         1       1        3       3         0
#
#        user_type            problems          spc_common  ...   nta  \
# 0              2                 NaN         English oak  ...  QN45
# 1              2                 NaN  crimson king maple  ...  BX05
# 2              2  StonesBranchLights         English oak  ...  SI01
# 3              0                 NaN         honeylocust  ...  SI11
# 4              2              Stones    London planetree  ...  MN03
# ...          ...                 ...                 ...  ...   ...
# 19979          2                 NaN         shingle oak  ...  SI24
# 19980          0                 NaN             catalpa  ...  SI32
# 19981          2                 NaN         English oak  ...  SI48
# 19982          0                 NaN   littleleaf linden  ...  MN25
# 19983          0              Stones         honeylocust  ...  BX59
#
#                                                 nta_name borocode  boro_ct  \
# 0                   Douglas Manor-Douglaston-Little Neck        4  4152901
# 1                             Bedford Park-Fordham North        2  2039901
# 2             Annadale-Huguenot-Prince's Bay-Eltingville        5  5017011
# 3                 Charleston-Richmond Valley-Tottenville        5  5024401
# 4                      Central Harlem North-Polo Grounds        1  1022102
# ...                                                  ...      ...      ...
# 19979  Todt Hill-Emerson Hill-Heartland Village-Light...        5  5018100
# 19980                                  Rossville-Woodrow        5  5020804
# 19981                                      Arden Heights        5  5017010
# 19982                  Battery Park City-Lower Manhattan        1  1031704
# 19983                              Westchester-Unionport        2  2007800
#
#        boroname       zip_city cb_num  st_senate  st_assem  cncldist
# 0             3    Little Neck    411         11        25        23
# 1             0          Bronx    207         33        78        15
# 2             4  Staten Island    503         24        62        51
# 3             4  Staten Island    503         24        62        51
# 4             2       New York    110         30        70         9
# ...         ...            ...    ...        ...       ...       ...
# 19979         4  Staten Island    502         24        62        50
# 19980         4  Staten Island    503         24        62        51
# 19981         4  Staten Island    503         24        62        51
# 19982         2       New York    101         26        65         1
# 19983         0          Bronx    209         32        87        18
#
# [19984 rows x 21 columns]
#        created_at  tree_dbh  curb_loc  steward  guards  sidewalk  user_type  \
# 19984  2015-09-08        15         1        3       3         0          0
# 19985  2015-10-15         5         1        0       3         1          2
# 19986  2016-08-03         4         1        3       2         1          2
# 19987  2015-08-06         7         1        3       3         1          1
# 19988  2015-10-21         6         1        0       1         1          1
# ...           ...       ...       ...      ...     ...       ...        ...
# 39964  2015-09-10         3         1        0       0         0          2
# 39965  2016-09-09         9         1        0       3         1          0
# 39966  2015-12-31        16         1        3       3         0          2
# 39967  2016-09-07        24         1        3       3         0          1
# 39968  2016-09-12        25         1        3       3         1          1
#
#                              problems         spc_common  \
# 19984                             NaN       Callery pear
# 19985                             NaN             cherry
# 19986                             NaN  littleleaf linden
# 19987                             NaN       dawn redwood
# 19988                          Stones   purple-leaf plum
# ...                               ...                ...
# 39964                 StonesRootOther  Japanese snowbell
# 39965                             NaN       silver maple
# 39966                             NaN       Callery pear
# 39967  RootOtherTrunkOtherBranchOther   London planetree
# 39968                          Stones   London planetree
#
#                           spc_latin   nta  \
# 19984              Pyrus calleryana  BK17
# 19985                        Prunus  BX62
# 19986                 Tilia cordata  QN60
# 19987  Metasequoia glyptostroboides  BK09
# 19988             Prunus cerasifera  BK75
# ...                             ...   ...
# 39964              Styrax japonicus  SI45
# 39965              Acer saccharinum  QN23
# 39966              Pyrus calleryana  BX01
# 39967         Platanus x acerifolia  BK79
# 39968         Platanus x acerifolia  SI24
#
#                                                 nta_name  borocode  boro_ct  \
# 19984     Sheepshead Bay-Gerritsen Beach-Manhattan Beach         3  3062000
# 19985                                 Woodlawn-Wakefield         2  2045101
# 19986                                        Kew Gardens         4  4013800
# 19987                       Brooklyn Heights-Cobble Hill         3  3000301
# 19988                                            Bedford         3  3025100
# ...                                                  ...       ...      ...
# 39964                             New Dorp-Midland Beach         5  5012200
# 39965                                      College Point         4  4093900
# 39966                                 Claremont-Bathgate         2  2039500
# 39967                                         Ocean Hill         3  3037300
# 39968  Todt Hill-Emerson Hill-Heartland Village-Light...         5  5017700
#
#        boroname       zip_city  cb_num  st_senate  st_assem  cncldist
# 19984         1       Brooklyn     315         22        45        48
# 19985         0          Bronx     212         34        81        11
# 19986         3    Kew Gardens     409         14        27        29
# 19987         1       Brooklyn     302         26        52        33
# 19988         1       Brooklyn     303         25        56        36
# ...         ...            ...     ...        ...       ...       ...
# 39964         4  Staten Island     502         24        64        50
# 39965         3  College Point     407         11        27        19
# 39966         0          Bronx     206         33        86        15
# 39967         1       Brooklyn     316         25        55        41
# 39968         4  Staten Island     502         24        63        50
#
# [19702 rows x 20 columns]

# %%
# カテゴリカル変数の要素一覧を表示
categorical_variables = ['curb_loc', 'steward', 'guards', 'sidewalk', 'user_type',
                          'problems', 'spc_common', 'spc_latin', 'nta', 'nta_name',
                          'boroname', 'zip_city']

for col in categorical_variables:
    unique_elements = train[col].unique()
    print(f'{col}の要素: {unique_elements}')
# Out:
# curb_locの要素: ['OnCurb' 'OffsetFromCurb']
# stewardの要素: [nan '3or4' '1or2' '4orMore']
# guardsの要素: [nan 'Helpful' 'Harmful' 'Unsure']
# sidewalkの要素: ['Damage' 'NoDamage']
# user_typeの要素: ['Volunteer' 'NYC Parks Staff' 'TreesCount Staff']
# problemsの要素: [nan 'StonesBranchLights' 'Stones' 'BranchLights' 'StonesTrunkOther'
#  'StonesWiresRopeBranchLights' 'StonesWiresRope' 'WiresRope' 'MetalGrates'
#  'RootOtherTrunkOtherBranchOther' 'StonesTrunkOtherBranchOther'
#  'RootOther' 'TrunkOtherBranchLightsBranchOther'
#  'MetalGratesRootOtherBranchOther'
#  'StonesWiresRopeTrunkLightsBranchLights' 'MetalGratesRootOtherTrunkOther'
#  'StonesMetalGrates' 'StonesRootOtherBranchOther' 'StonesRootOther'
#  'BranchOther' 'TrunkOther' 'TrunkOtherBranchOther'
#  'StonesTrunkOtherBranchLightsBranchOther'
#  'StonesRootOtherWiresRopeTrunkOtherBranchLightsBranchOther'
#  'StonesBranchOther' 'WiresRopeBranchLights'
#  'RootOtherWiresRopeBranchOther' 'TrunkOtherBranchLights'
#  'RootOtherWiresRopeTrunkOtherBranchOther' 'StonesRootOtherTrunkOther'
#  'MetalGratesBranchOther' 'TrunkLightsBranchLights' 'RootOtherTrunkOther'
#  'StonesBranchLightsBranchOther' 'RootOtherBranchLights'
#  'StonesWiresRopeTrunkOther' 'WiresRopeBranchOther'
#  'MetalGratesTrunkOtherBranchOther'
#  'StonesWiresRopeTrunkOtherBranchLights' 'TrunkLights'
#  'RootOtherTrunkOtherBranchLightsBranchOther'
#  'StonesWiresRopeBranchLightsBranchOther'
#  'StonesMetalGratesWiresRopeTrunkLightsBranchLights'
#  'RootOtherBranchOther' 'WiresRopeTrunkOtherBranchOther'
#  'RootOtherWiresRope' 'StonesTrunkOtherBranchLights'
#  'StonesTrunkLightsBranchLights'
#  'RootOtherWiresRopeBranchLightsBranchOther'
#  'StonesMetalGratesBranchLights' 'StonesRootOtherBranchLightsBranchOther'
#  'BranchLightsBranchOther' 'RootOtherWiresRopeTrunkLights'
#  'StonesWiresRopeBranchOther' 'TrunkLightsBranchLightsBranchOther'
#  'RootOtherWiresRopeTrunkOther' 'RootOtherWiresRopeTrunkOtherBranchLights'
#  'StonesRootOtherTrunkOtherBranchLights'
#  'WiresRopeTrunkOtherBranchLightsBranchOther'
#  'WiresRopeTrunkLightsBranchLights' 'RootOtherTrunkOtherBranchLights'
#  'StonesMetalGratesTrunkOther' 'RootOtherWiresRopeBranchLights'
#  'StonesRootOtherWiresRopeBranchLights' 'WiresRopeTrunkLights'
#  'StonesSneakers' 'MetalGratesWiresRope'
#  'StonesRootOtherWiresRopeBranchOther' 'MetalGratesTrunkOther'
#  'WiresRopeTrunkOther' 'RootOtherBranchLightsBranchOther'
#  'StonesRootOtherBranchLights' 'StonesRootOtherTrunkOtherBranchOther'
#  'RootOtherTrunkLightsBranchOther']
# spc_commonの要素: ['English oak' 'crimson king maple' 'honeylocust' 'London planetree'
#  'Amur cork tree' 'littleleaf linden' 'cherry' 'Siberian elm'
#  'Norway maple' 'Japanese zelkova' 'green ash' 'American elm'
#  'Kentucky coffeetree' 'Amur maackia' 'silver linden' "Schumard's oak"
#  'pin oak' 'red horse chestnut' 'American hornbeam' 'silver maple'
#  'ginkgo' 'Callery pear' 'Turkish hazelnut' 'Amur maple' 'American linden'
#  'catalpa' 'Sophora' 'katsura tree' 'maple' 'American hophornbeam'
#  'bur oak' 'cockspur hawthorn' 'Japanese tree lilac' 'eastern hemlock'
#  'sassafras' 'sawtooth oak' 'willow oak' 'black oak' 'eastern redbud'
#  'sweetgum' 'scarlet oak' 'purple-leaf plum' "'Schubert' chokecherry"
#  'Chinese elm' 'dawn redwood' 'Chinese fringetree' 'American beech'
#  'red maple' 'tartar maple' 'sycamore maple' 'swamp white oak' 'holly'
#  'northern red oak' 'ash' 'Ohio buckeye' 'Cornelian cherry' 'black walnut'
#  'crab apple' 'hawthorn' 'silver birch' 'black locust' 'hedge maple'
#  'Persian ironwood' 'Norway spruce' 'eastern redcedar' 'blue spruce'
#  'white ash' 'Atlantic white cedar' 'Japanese maple' 'white oak'
#  'sugar maple' 'hardy rubber tree' 'paper birch' 'serviceberry'
#  'empress tree' 'mulberry' 'bald cypress' 'spruce' 'horse chestnut'
#  'two-winged silverbell' 'eastern cottonwood' 'golden raintree'
#  'Himalayan cedar' 'Shantung maple' 'flowering dogwood' 'pitch pine'
#  'red pine' 'black cherry' 'kousa dogwood' 'cucumber magnolia'
#  'Kentucky yellowwood' 'common hackberry' 'Atlas cedar' 'weeping willow'
#  'crepe myrtle' 'European hornbeam' 'shingle oak' 'Japanese hornbeam'
#  'pond cypress' 'white pine' 'quaking aspen' 'Japanese snowbell'
#  'magnolia' 'European beech' 'paperbark maple' 'false cypress'
#  'bigtooth aspen' 'arborvitae' 'blackgum' 'pagoda dogwood' 'trident maple'
#  'Chinese chestnut' 'pignut hickory' 'river birch' 'tulip-poplar'
#  'tree of heaven' 'Chinese tree lilac' 'southern magnolia'
#  'Oklahoma redbud' 'pine']
# spc_latinの要素: ['Quercus robur' "Acer platanoides 'Crimson King'"
#  'Gleditsia triacanthos var. inermis' 'Platanus x acerifolia'
#  'Phellodendron amurense' 'Tilia cordata' 'Prunus' 'Ulmus pumila'
#  'Acer platanoides' 'Zelkova serrata' 'Fraxinus pennsylvanica'
#  'Ulmus americana' 'Gymnocladus dioicus' 'Maackia amurensis'
#  'Tilia tomentosa' 'Quercus shumardii' 'Quercus palustris'
#  'Aesculus x carnea' 'Carpinus caroliniana' 'Acer saccharinum'
#  'Ginkgo biloba' 'Pyrus calleryana' 'Corylus colurna' 'Acer ginnala'
#  'Tilia americana' 'Catalpa' 'Styphnolobium japonicum'
#  'Cercidiphyllum japonicum' 'Acer' 'Ostrya virginiana'
#  'Quercus macrocarpa' 'Crataegus crusgalli var. inermis'
#  'Syringa reticulata' 'Tsuga canadensis' 'Sassafras albidum'
#  'Quercus acutissima' 'Quercus phellos' 'Quercus velutina'
#  'Cercis canadensis' 'Liquidambar styraciflua' 'Quercus coccinea'
#  'Prunus cerasifera' 'Prunus virginiana' 'Ulmus parvifolia'
#  'Metasequoia glyptostroboides' 'Chionanthus retusus' 'Fagus grandifolia'
#  'Acer rubrum' 'Acer tataricum' 'Acer pseudoplatanus' 'Quercus bicolor'
#  'Ilex' 'Quercus rubra' 'Fraxinus' 'Aesculus glabra' 'Cornus mas'
#  'Juglans nigra' 'Malus' 'Crataegus' 'Betula pendula'
#  'Robinia pseudoacacia' 'Acer campestre' 'Parrotia persica' 'Picea abies'
#  'Juniperus virginiana' 'Picea pungens' 'Fraxinus americana'
#  'Chamaecyparis thyoides' 'Acer palmatum' 'Quercus alba' 'Acer saccharum'
#  'Eucommia ulmoides' 'Betula papyrifera' 'Amelanchier'
#  'Paulownia tomentosa' 'Morus' 'Taxodium distichum' 'Picea'
#  'Aesculus hippocastanum' 'Halesia diptera' 'Populus deltoides'
#  'Koelreuteria paniculata' 'Cedrus deodara' 'Acer truncatum'
#  'Cornus florida' 'Pinus rigida' 'Pinus resinosa' 'Prunus serotina'
#  'Cornus kousa' 'Magnolia acuminata' 'Cladrastis kentukea'
#  'Celtis occidentalis' 'Cedrus atlantica' 'Salix babylonica'
#  'Lagerstroemia' 'Carpinus betulus' 'Quercus imbricaria'
#  'Carpinus japonica' 'Taxodium ascendens' 'Pinus strobus'
#  'Populus tremuloides' 'Styrax japonicus' 'Magnolia' 'Fagus sylvatica'
#  'Acer griseum' 'Chamaecyparis pisifera' 'Populus grandidentata'
#  'Thuja occidentalis' 'Nyssa sylvatica' 'Cornus alternifolia'
#  'Acer buergerianum' 'Castanea mollissima' 'Carya glabra' 'Betula nigra'
#  'Liriodendron tulipifera' 'Ailanthus altissima' 'Syringa pekinensis'
#  'Magnolia grandiflora' 'Cercis reniformis' 'Pinus']
# ntaの要素: ['QN45' 'BX05' 'SI01' 'SI11' 'MN03' 'QN22' 'QN08' 'BK82' 'QN52' 'QN56'
#  'SI45' 'BK76' 'SI25' 'QN49' 'QN37' 'SI07' 'SI32' 'BK90' 'MN23' 'BK26'
#  'QN05' 'QN42' 'QN29' 'SI48' 'BK61' 'MN36' 'SI28' 'MN35' 'MN12' 'QN43'
#  'QN17' 'QN21' 'MN15' 'QN61' 'BK95' 'QN20' 'BX59' 'BK45' 'QN28' 'BK35'
#  'QN19' 'MN34' 'QN50' 'QN70' 'QN31' 'QN33' 'QN23' 'QN10' 'BK37' 'SI05'
#  'BK38' 'BK33' 'MN40' 'BK81' 'BX34' 'BK31' 'BK77' 'BK17' 'BK68' 'MN25'
#  'SI35' 'QN55' 'SI36' 'QN72' 'SI54' 'BX03' 'QN03' 'BX13' 'BK44' 'QN25'
#  'BK28' 'QN54' 'BK88' 'QN30' 'QN01' 'BK73' 'BX06' 'BX49' 'BX39' 'BX07'
#  'MN27' 'MN32' 'QN57' 'BK79' 'BX10' 'BX36' 'QN76' 'MN31' 'BK42' 'BK29'
#  'MN14' 'SI24' 'QN71' 'BK09' 'QN44' 'QN12' 'BX55' 'MN24' 'BX14' 'BK58'
#  'SI22' 'SI08' 'MN13' 'SI37' 'MN22' 'QN35' 'BX01' 'BK43' 'BK41' 'BK83'
#  'QN46' 'BX37' 'QN66' 'QN51' 'BK40' 'BX27' 'QN48' 'QN02' 'BK69' 'BK64'
#  'BX44' 'MN19' 'BK93' 'SI14' 'MN09' 'BX52' 'BK63' 'BX75' 'BX33' 'BK72'
#  'BX26' 'BK50' 'BK30' 'BK75' 'MN11' 'QN34' 'BK91' 'BX08' 'BX29' 'BX40'
#  'QN15' 'BX09' 'BK25' 'BK32' 'QN06' 'MN28' 'SI12' 'QN62' 'MN06' 'QN27'
#  'QN47' 'BX62' 'BK78' 'BX46' 'BX35' 'QN38' 'MN33' 'BK85' 'BK46' 'QN07'
#  'BK34' 'QN60' 'BK21' 'BK23' 'QN53' 'QN26' 'MN04' 'BX31' 'BX30' 'MN01'
#  'BX63' 'BX28' 'BX43' 'BK96' 'QN41' 'BX17' 'QN18' 'BX22' 'BK60' 'QN63'
#  'BX41' 'BK19' 'QN68' 'MN20' 'MN17' 'MN21' 'BK27']
# nta_nameの要素: ['Douglas Manor-Douglaston-Little Neck' 'Bedford Park-Fordham North'
#  "Annadale-Huguenot-Prince's Bay-Eltingville"
#  'Charleston-Richmond Valley-Tottenville'
#  'Central Harlem North-Polo Grounds' 'Flushing' 'St. Albans'
#  'East New York' 'East Flushing' 'Ozone Park' 'New Dorp-Midland Beach'
#  'Greenpoint' 'Oakwood-Oakwood Beach' 'Whitestone' 'Kew Gardens Hills'
#  'Westerleigh' 'Rossville-Woodrow' 'East Williamsburg' 'West Village'
#  'Gravesend' 'Rosedale' 'Oakland Gardens' 'Elmhurst' 'Arden Heights'
#  'Crown Heights North' 'Washington Heights South' 'Port Richmond'
#  'Washington Heights North' 'Upper West Side' 'Bellerose' 'Forest Hills'
#  'Middle Village' 'Clinton' 'Jamaica' 'Erasmus' 'Ridgewood'
#  'Westchester-Unionport' 'Georgetown-Marine Park-Bergen Beach-Mill Basin'
#  'Jackson Heights' 'Stuyvesant Heights' 'Glendale' 'East Harlem North'
#  'Elmhurst-Maspeth' 'Astoria' 'Hunters Point-Sunnyside-West Maspeth'
#  'Cambria Heights' 'College Point'
#  'Breezy Point-Belle Harbor-Rockaway Park-Broad Channel'
#  'Park Slope-Gowanus' 'New Springville-Bloomfield-Travis'
#  'DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill'
#  'Carroll Gardens-Columbia Street-Red Hook'
#  'Upper East Side-Carnegie Hill' 'Brownsville'
#  'Melrose South-Mott Haven North' 'Bay Ridge' 'Bushwick North'
#  'Sheepshead Bay-Gerritsen Beach-Manhattan Beach' 'Fort Greene'
#  'Battery Park City-Lower Manhattan' 'New Brighton-Silver Lake'
#  'South Ozone Park' 'Old Town-Dongan Hills-South Beach' 'Steinway'
#  'Great Kills' 'Eastchester-Edenwald-Baychester'
#  'Springfield Gardens South-Brookville' 'Co-op City' 'Madison' 'Corona'
#  'Bensonhurst West' 'Richmond Hill' 'Borough Park' 'Maspeth'
#  'South Jamaica' 'North Side-South Side' 'Belmont' 'Pelham Parkway'
#  'Mott Haven-Port Morris' 'Bronxdale' 'Chinatown' 'Yorkville'
#  'Lindenwood-Howard Beach' 'Ocean Hill'
#  'Pelham Bay-Country Club-City Island' 'University Heights-Morris Heights'
#  'Baisley Park' 'Lenox Hill-Roosevelt Island' 'Flatbush'
#  'Bensonhurst East' 'Lincoln Square'
#  'Todt Hill-Emerson Hill-Heartland Village-Lighthouse Hill' 'Old Astoria'
#  'Brooklyn Heights-Cobble Hill' 'Glen Oaks-Floral Park-New Hyde Park'
#  'Hammels-Arverne-Edgemere' 'Soundview-Bruckner'
#  'SoHo-TriBeCa-Civic Center-Little Italy'
#  'East Concourse-Concourse Village' 'Flatlands'
#  'West New Brighton-New Brighton-St. George'
#  'Grymes Hill-Clifton-Fox Hills'
#  'Hudson Yards-Chelsea-Flatiron-Union Square' 'Stapleton-Rosebank'
#  'East Village' 'Briarwood-Jamaica Hills' 'Claremont-Bathgate' 'Midwood'
#  'Kensington-Ocean Parkway' 'Cypress Hills-City Line'
#  'Bayside-Bayside Hills' 'Van Nest-Morris Park-Westchester Square'
#  'Laurelton' 'Murray Hill' 'Windsor Terrace' 'Hunts Point' 'Auburndale'
#  'Springfield Gardens North' 'Clinton Hill' 'Prospect Heights'
#  'Williamsbridge-Olinville' 'Turtle Bay-East Midtown' 'Starrett City'
#  'Grasmere-Arrochar-Ft. Wadsworth' 'Morningside Heights'
#  'Schuylerville-Throgs Neck-Edgewater Park' 'Crown Heights South'
#  'Crotona Park East' 'Longwood' 'Williamsburg' 'Highbridge' 'Canarsie'
#  'Dyker Heights' 'Bedford' 'Central Harlem South' 'Queens Village'
#  'East Flatbush-Farragut' 'West Farms-Bronx River'
#  'Spuyten Duyvil-Kingsbridge' 'Fordham South' 'Far Rockaway-Bayswater'
#  'Soundview-Castle Hill-Clason Point-Harding Park' 'Homecrest'
#  'Sunset Park West' 'Jamaica Estates-Holliswood' 'Lower East Side'
#  "Mariner's Harbor-Arlington-Port Ivory-Graniteville" 'Queensboro Hill'
#  'Manhattanville' 'East Elmhurst' 'Ft. Totten-Bay Terrace-Clearview'
#  'Woodlawn-Wakefield' 'Bushwick South' 'Parkchester' 'Morrisania-Melrose'
#  'Pomonok-Flushing Heights-Hillcrest' 'East Harlem South'
#  'East New York (Pennsylvania Ave)' 'Ocean Parkway South' 'Hollis'
#  'Sunset Park East' 'Kew Gardens' 'Seagate-Coney Island' 'West Brighton'
#  'Woodhaven' 'North Corona' 'Hamilton Heights' 'Allerton-Pelham Gardens'
#  'Kingsbridge Heights' 'Marble Hill-Inwood' 'West Concourse'
#  'Van Cortlandt Village' 'Norwood' 'Rugby-Remsen Village'
#  'Fresh Meadows-Utopia' 'East Tremont' 'Rego Park'
#  'North Riverdale-Fieldston-Riverdale' 'Prospect Lefferts Gardens-Wingate'
#  'Woodside' 'Mount Hope' 'Brighton Beach'
#  'Queensbridge-Ravenswood-Long Island City' 'Murray Hill-Kips Bay'
#  'Midtown-Midtown South' 'Gramercy' 'Bath Beach']
# boronameの要素: ['Queens' 'Bronx' 'Staten Island' 'Manhattan' 'Brooklyn']
# zip_cityの要素: ['Little Neck' 'Bronx' 'Staten Island' 'New York' 'Flushing'
#  'Saint Albans' 'Brooklyn' 'Ozone Park' 'Whitestone' 'Jamaica' 'Rosedale'
#  'Oakland Gardens' 'Elmhurst' 'Bellerose' 'Forest Hills' 'Middle Village'
#  'Queens Village' 'Ridgewood' 'Jackson Heights' 'East Elmhurst' 'Woodside'
#  'Astoria' 'Long Island City' 'Cambria Heights' 'Rockaway Park'
#  'South Richmond Hill' 'Springfield Gardens' 'Corona' 'Richmond Hill'
#  'Central Park' 'Maspeth' 'Howard Beach' 'South Ozone Park' 'Glen Oaks'
#  'Arverne' 'Bayside' 'Fresh Meadows' 'Sunnyside' 'College Point'
#  'Far Rockaway' 'Hollis' 'Kew Gardens' 'Woodhaven' 'Rego Park'
#  'Floral Park']

# %%
from sklearn.preprocessing import LabelEncoder

# カテゴリ変数を数値化する関数
def encode_categorical_variables(df, categorical_variables):
    le = LabelEncoder()
    for col in categorical_variables:
        df[col] = le.fit_transform(df[col].astype(str))
    return df

# カテゴリ変数の要素一覧を表示
categorical_variables = ['curb_loc', 'steward', 'guards', 'sidewalk', 'user_type', 'boroname']

for col in categorical_variables:
    unique_elements = train[col].unique()
    print(f'{col}の要素: {unique_elements}')

# カテゴリ変数を数値化
train_encoded = encode_categorical_variables(train, categorical_variables)
test_encoded = encode_categorical_variables(test, categorical_variables)

print(train_encoded)
print(test_encoded)
# Out:
# curb_locの要素: [1 0]
# stewardの要素: [3 1 0 2]
# guardsの要素: [3 1 0 2]
# sidewalkの要素: [0 1]
# user_typeの要素: [2 0 1]
# boronameの要素: [3 0 4 2 1]
#        created_at  tree_dbh  curb_loc  health  steward  guards  sidewalk  \
# 0      2015-06-29        14         1       1        3       3         0
# 1      2016-09-21         5         1       1        1       1         1
# 2      2015-09-13        26         1       2        3       3         1
# 3      2016-05-09        15         1       0        3       3         0
# 4      2016-06-24        23         1       1        3       3         1
# ...           ...       ...       ...     ...      ...     ...       ...
# 19979  2016-07-15        19         1       2        3       3         0
# 19980  2016-07-08         5         1       1        3       3         1
# 19981  2015-08-20        21         1       0        3       3         0
# 19982  2016-06-20         4         1       1        0       3         1
# 19983  2015-08-19        31         1       1        3       3         0
#
#        user_type            problems          spc_common  ...   nta  \
# 0              2                 NaN         English oak  ...  QN45
# 1              2                 NaN  crimson king maple  ...  BX05
# 2              2  StonesBranchLights         English oak  ...  SI01
# 3              0                 NaN         honeylocust  ...  SI11
# 4              2              Stones    London planetree  ...  MN03
# ...          ...                 ...                 ...  ...   ...
# 19979          2                 NaN         shingle oak  ...  SI24
# 19980          0                 NaN             catalpa  ...  SI32
# 19981          2                 NaN         English oak  ...  SI48
# 19982          0                 NaN   littleleaf linden  ...  MN25
# 19983          0              Stones         honeylocust  ...  BX59
#
#                                                 nta_name borocode  boro_ct  \
# 0                   Douglas Manor-Douglaston-Little Neck        4  4152901
# 1                             Bedford Park-Fordham North        2  2039901
# 2             Annadale-Huguenot-Prince's Bay-Eltingville        5  5017011
# 3                 Charleston-Richmond Valley-Tottenville        5  5024401
# 4                      Central Harlem North-Polo Grounds        1  1022102
# ...                                                  ...      ...      ...
# 19979  Todt Hill-Emerson Hill-Heartland Village-Light...        5  5018100
# 19980                                  Rossville-Woodrow        5  5020804
# 19981                                      Arden Heights        5  5017010
# 19982                  Battery Park City-Lower Manhattan        1  1031704
# 19983                              Westchester-Unionport        2  2007800
#
#        boroname       zip_city cb_num  st_senate  st_assem  cncldist
# 0             3    Little Neck    411         11        25        23
# 1             0          Bronx    207         33        78        15
# 2             4  Staten Island    503         24        62        51
# 3             4  Staten Island    503         24        62        51
# 4             2       New York    110         30        70         9
# ...         ...            ...    ...        ...       ...       ...
# 19979         4  Staten Island    502         24        62        50
# 19980         4  Staten Island    503         24        62        51
# 19981         4  Staten Island    503         24        62        51
# 19982         2       New York    101         26        65         1
# 19983         0          Bronx    209         32        87        18
#
# [19984 rows x 21 columns]
#        created_at  tree_dbh  curb_loc  steward  guards  sidewalk  user_type  \
# 19984  2015-09-08        15         1        3       3         0          0
# 19985  2015-10-15         5         1        0       3         1          2
# 19986  2016-08-03         4         1        3       2         1          2
# 19987  2015-08-06         7         1        3       3         1          1
# 19988  2015-10-21         6         1        0       1         1          1
# ...           ...       ...       ...      ...     ...       ...        ...
# 39964  2015-09-10         3         1        0       0         0          2
# 39965  2016-09-09         9         1        0       3         1          0
# 39966  2015-12-31        16         1        3       3         0          2
# 39967  2016-09-07        24         1        3       3         0          1
# 39968  2016-09-12        25         1        3       3         1          1
#
#                              problems         spc_common  \
# 19984                             NaN       Callery pear
# 19985                             NaN             cherry
# 19986                             NaN  littleleaf linden
# 19987                             NaN       dawn redwood
# 19988                          Stones   purple-leaf plum
# ...                               ...                ...
# 39964                 StonesRootOther  Japanese snowbell
# 39965                             NaN       silver maple
# 39966                             NaN       Callery pear
# 39967  RootOtherTrunkOtherBranchOther   London planetree
# 39968                          Stones   London planetree
#
#                           spc_latin   nta  \
# 19984              Pyrus calleryana  BK17
# 19985                        Prunus  BX62
# 19986                 Tilia cordata  QN60
# 19987  Metasequoia glyptostroboides  BK09
# 19988             Prunus cerasifera  BK75
# ...                             ...   ...
# 39964              Styrax japonicus  SI45
# 39965              Acer saccharinum  QN23
# 39966              Pyrus calleryana  BX01
# 39967         Platanus x acerifolia  BK79
# 39968         Platanus x acerifolia  SI24
#
#                                                 nta_name  borocode  boro_ct  \
# 19984     Sheepshead Bay-Gerritsen Beach-Manhattan Beach         3  3062000
# 19985                                 Woodlawn-Wakefield         2  2045101
# 19986                                        Kew Gardens         4  4013800
# 19987                       Brooklyn Heights-Cobble Hill         3  3000301
# 19988                                            Bedford         3  3025100
# ...                                                  ...       ...      ...
# 39964                             New Dorp-Midland Beach         5  5012200
# 39965                                      College Point         4  4093900
# 39966                                 Claremont-Bathgate         2  2039500
# 39967                                         Ocean Hill         3  3037300
# 39968  Todt Hill-Emerson Hill-Heartland Village-Light...         5  5017700
#
#        boroname       zip_city  cb_num  st_senate  st_assem  cncldist
# 19984         1       Brooklyn     315         22        45        48
# 19985         0          Bronx     212         34        81        11
# 19986         3    Kew Gardens     409         14        27        29
# 19987         1       Brooklyn     302         26        52        33
# 19988         1       Brooklyn     303         25        56        36
# ...         ...            ...     ...        ...       ...       ...
# 39964         4  Staten Island     502         24        64        50
# 39965         3  College Point     407         11        27        19
# 39966         0          Bronx     206         33        86        15
# 39967         1       Brooklyn     316         25        55        41
# 39968         4  Staten Island     502         24        63        50
#
# [19702 rows x 20 columns]

# %%
# 欠損値の処理
train.fillna('NULL', inplace=True)
test.fillna('NULL', inplace=True)

# problems列の処理
train['bool_problems'] = train['problems'].apply(lambda x: 0 if x=='NULL' else 1)
test['bool_problems'] = test['problems'].apply(lambda x: 0 if x=='NULL' else 1)

# 学習用データと検証用データの分割
train, valid = train_test_split(train, test_size=0.2, stratify=train['health'], random_state=82)

# 使用する特徴量の選択
select_cols = ['tree_dbh', 'curb_loc', 'sidewalk', 'steward', 'guards', 'user_type', 'bool_problems']

# 目的変数とそれ以外に学習用データを分割
x_train = train[select_cols]
y_train = train['health']
x_valid = valid[select_cols]
y_valid = valid['health']

# カテゴリのままでは学習できないのでワンホットエンコーディングで数値化
x_train = pd.get_dummies(x_train)
x_valid = pd.get_dummies(x_valid)
test = pd.get_dummies(test[select_cols])

# AutoML（TPOT）を使用
tpot = TPOTClassifier(generations=5, population_size=20, random_state=42, verbosity=2, n_jobs=-1)
tpot.fit(x_train, y_train)

# 検証データでの評価
valid_predictions = tpot.predict(x_valid)
valid_f1 = f1_score(y_valid, valid_predictions, average='macro')
print(f"Validation F1 Score (Macro): {valid_f1}")

# 予測
pred = tpot.predict(test)

# 予測結果の保存
sample_submit[1] = pred
sample_submit.to_csv('./submit/submit_automl_v1.csv', header=None)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tpot import TPOTClassifier
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder

# データの読み込み
train = pd.read_csv('./source/train.csv', index_col=0)
test = pd.read_csv('./source/test.csv', index_col=0)
sample_submit = pd.read_csv('./source/sample_submission.csv', index_col=0, header=None)

# 欠損値の処理
train.fillna('NULL', inplace=True)
test.fillna('NULL', inplace=True)

# problems列の処理
train['bool_problems'] = train['problems'].apply(lambda x: 0 if x == 'NULL' else 1)
test['bool_problems'] = test['problems'].apply(lambda x: 0 if x == 'NULL' else 1)

# カテゴリ変数を数値化する関数
def encode_categorical_variables(df, categorical_variables):
    le = LabelEncoder()
    for col in categorical_variables:
        df[col] = le.fit_transform(df[col].astype(str))
    return df

# カテゴリ変数の要素一覧を表示
categorical_variables = ['curb_loc', 'steward', 'guards', 'sidewalk', 'user_type', 'boroname']

for col in categorical_variables:
    unique_elements = train[col].unique()
    print(f'{col}の要素: {unique_elements}')

# カテゴリ変数を数値化
train_encoded = encode_categorical_variables(train, categorical_variables)
test_encoded = encode_categorical_variables(test, categorical_variables)

# 学習用データと検証用データの分割
train_encoded, valid = train_test_split(train_encoded, test_size=0.2, stratify=train_encoded['health'], random_state=82)

# 使用する特徴量の選択
select_cols = ['tree_dbh', 'curb_loc', 'sidewalk', 'steward', 'guards', 'user_type', 'bool_problems']

# 目的変数とそれ以外に学習用データを分割
x_train = train_encoded[select_cols]
y_train = train_encoded['health']
x_valid = valid[select_cols]
y_valid = valid['health']

# カテゴリのままでは学習できないのでワンホットエンコーディングで数値化
x_train = pd.get_dummies(x_train)
x_valid = pd.get_dummies(x_valid)
test = pd.get_dummies(test_encoded[select_cols])

# AutoML（TPOT）を使用
tpot = TPOTClassifier(generations=5, population_size=20, random_state=42, verbosity=2, n_jobs=-1)
tpot.fit(x_train, y_train)

# 検証データでの評価
valid_predictions = tpot.predict(x_valid)
valid_f1 = f1_score(y_valid, valid_predictions, average='macro')
print(f"Validation F1 Score (Macro): {valid_f1}")

# 予測
pred = tpot.predict(test)

# 予測結果の保存
sample_submit[1] = pred
sample_submit.to_csv('./submit/submit_automl_v2.csv', header=None)
# Out:
# curb_locの要素: ['OnCurb' 'OffsetFromCurb']
# stewardの要素: ['NULL' '3or4' '1or2' '4orMore']
# guardsの要素: ['NULL' 'Helpful' 'Harmful' 'Unsure']
# sidewalkの要素: ['Damage' 'NoDamage']
# user_typeの要素: ['Volunteer' 'NYC Parks Staff' 'TreesCount Staff']
# boronameの要素: ['Queens' 'Bronx' 'Staten Island' 'Manhattan' 'Brooklyn']
#
# Generation 1 - Current best internal CV score: 0.7882029607572608
#
# Generation 2 - Current best internal CV score: 0.7882029607572608
#
# Generation 3 - Current best internal CV score: 0.7882029607572608
#
# Generation 4 - Current best internal CV score: 0.7882654802823865
#
# Generation 5 - Current best internal CV score: 0.7883280584929235
#
# Best pipeline: GradientBoostingClassifier(input_matrix, learning_rate=0.5, max_depth=1, max_features=0.5, min_samples_leaf=3, min_samples_split=3, n_estimators=100, subsample=0.35000000000000003)
# Validation F1 Score (Macro): 0.29367301231802917
